# %%
print("ALL GOOD")
# Out:
# ALL GOOD

# %%
import pandas as pd
from sqlalchemy import create_engine
import pyodbc

# %%
username = 'sqluserai'
password = 'Aditya@123'
database = 'sqldbpocai'
server = 'sqlserverai.database.windows.net'
driver = {'ODBC Driver 18 for SQL Server'}

# %%
connection_string = f'mssql+pyodbc://{username}:{password}@{server}/{database}?driver=ODBC+Driver+18+for+SQL+Server'
engine = create_engine(connection_string)

# %%
engine
# Out:
# Engine(mssql+pyodbc://sqluserai:***@123@sqlserverai.database.windows.net/sqldbpocai?driver=ODBC+Driver+18+for+SQL+Server)

# %%
df = pd.read_csv('Bengaluru_House_Data.csv')

# %%
df.to_sql('Houseprice', con=engine, if_exists='replace', index=False)
# Out:
# ---------------------------------------------------------------------------
# InterfaceError                            Traceback (most recent call last)
# File ~\anaconda3\Lib\site-packages\sqlalchemy\engine\base.py:146, in Connection.__init__(self, engine, connection, _has_events, _allow_revalidate, _allow_autobegin)
#     145 try:
# --> 146     self._dbapi_connection = engine.raw_connection()
#     147 except dialect.loaded_dbapi.Error as err:
#
# File ~\anaconda3\Lib\site-packages\sqlalchemy\engine\base.py:3302, in Engine.raw_connection(self)
#    3281 """Return a "raw" DBAPI connection from the connection pool.
#    3282
#    3283 The returned object is a proxied version of the DBAPI
#    (...)
#    3300
#    3301 """
# -> 3302 return self.pool.connect()
#
# File ~\anaconda3\Lib\site-packages\sqlalchemy\pool\base.py:449, in Pool.connect(self)
#     442 """Return a DBAPI connection from the pool.
#     443
#     444 The connection is instrumented such that when its
#    (...)
# ...

# %%
df2 =  pd.read_sql('select * from Houseprice where balcony>2',engine)

# %%
df2

# %%
cursor.execute('select * from Houseprice where price>120 and balcony>2')

# %%
row = cursor.fetchall()

# %%
row
# Out:
# [('Plot  Area', 'Ready To Move', 'Whitefield', '4 Bedroom', 'Prrry M', '2785', 5.0, 3.0, 295.0),
#  ('Plot  Area', 'Ready To Move', 'Whitefield', '4 Bedroom', 'Chranya', '5700', 5.0, 3.0, 650.0),
#  ('Built-up  Area', 'Ready To Move', 'Cholanayakanahalli', '3 BHK', 'Viony H', '2511', 3.0, 3.0, 205.0),
#  ('Built-up  Area', 'Ready To Move', 'ISRO Layout', '6 Bedroom', None, '4400', 6.0, 3.0, 250.0),
#  ('Plot  Area', 'Ready To Move', 'Rajaji Nagar', '6 Bedroom', None, '710', 6.0, 3.0, 160.0),
#  ('Super built-up  Area', 'Ready To Move', 'Yeshwanthpur', '3 BHK', 'IBityin', '2502', 3.0, 3.0, 138.0),
#  ('Super built-up  Area', 'Ready To Move', 'Thanisandra', '3 BHK', 'Soitya ', '1735', 3.0, 3.0, 135.0),
#  ('Super built-up  Area', 'Ready To Move', 'JP Nagar', '3 BHK', 'Maerar ', '1850', 3.0, 3.0, 150.0),
#  ('Plot  Area', 'Ready To Move', 'Akshaya Vana', '4 Bedroom', None, '1200', 4.0, 3.0, 165.0),
# ...
